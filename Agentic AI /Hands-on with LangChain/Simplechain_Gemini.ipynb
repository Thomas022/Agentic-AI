# %%
#  Install required packages
# !pip install -qU langchain langchain_core langchain-google-genai google-generativeai==0.8.5

# %%
import os, sys, platform
from google.colab import userdata
from datetime import datetime

# LangChain + Gemini
import langchain, langchain_core
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import RunnablePassthrough

# %%
#  Set your Gemini API key
os.environ["GOOGLE_API_KEY"] = userdata.get("Gemini_APi_Key")

# %%
# Recommended for demos: fast & economical
model_name = "gemini-3.6-flash"

llm = ChatGoogleGenerativeAI(
    model=model_name,
    convert_system_message_to_human=True,  # smoother behavior with system prompts
    temperature=0.7,
)
print(f" Ready with model: {model_name}")
# Out:
#  Ready with model: gemini-3.6-flash

# %%
# First LLM call.
msg = "Explain AI in one friendly paragraph for a complete beginner."
resp = llm.invoke(msg)   # ChatModels accept a plain string or list of messages
print(resp.content)
# Out:
# /usr/local/lib/python3.12/dist-packages/langchain_google_genai/chat_models.py:3237: UserWarning: Model 'gemini-3.6-flash' uses fixed sampling defaults; the sampling parameter(s) temperature will be ignored.
#   request = self._build_request_config(
# [{'type': 'text', 'text': 'Think of Artificial Intelligence (AI) as a smart computer program that learns to do tasks that usually require human brainpower, like recognizing photos, translating languages, or solving tricky problems. Instead of just following strict, step-by-step instructions, AI learns by studying thousands of examples—much like how you learned to recognize a dog by seeing lots of different dogs over time. You actually interact with AI every day without realizing it: it’s what suggests your next favorite song on Spotify, helps your phone recognize your face, or predicts the fastest route home on Google Maps. Simply put, AI is just clever technology designed to be a helpful assistant, making our daily lives a little bit easier and more connected.', 'extras': {'signature': '...'}}]

# %% [markdown]
# # PromptTemplate → Chain (Runnable)

# %%
# Build a motivational quote generator with a parameterized prompt
motivation_prompt = PromptTemplate.from_template(
    "Write a short, uplifting motivational quote for someone working as a {profession}. "
    "Keep it under 25 words."
)

# %%
# Compose: Prompt → LLM → String output
chain = motivation_prompt | llm | StrOutputParser()

# %%
print(" Example (profession=Data Scientist):")
print(chain.invoke({"profession": "Data Scientist"}))
# Out:
#  Example (profession=Data Scientist):
# /usr/local/lib/python3.12/dist-packages/langchain_google_genai/chat_models.py:3237: UserWarning: Model 'gemini-3.6-flash' uses fixed sampling defaults; the sampling parameter(s) temperature will be ignored.
#   request = self._build_request_config(
# You don't just analyze numbers—you uncover hidden truths that shape the future. Keep turning complex noise into world-changing clarity!

# %% [markdown]
# # Quick Playground helper

# %%
def ask(prompt: str):
    """Mini helper to chat with the model."""
    res = llm.invoke(prompt)
    return res.content

print(ask("How do i help law firm with the usage of Agentic AI"))
# Out:
# /usr/local/lib/python3.12/dist-packages/langchain_google_genai/chat_models.py:3237: UserWarning: Model 'gemini-3.6-flash' uses fixed sampling defaults; the sampling parameter(s) temperature will be ignored.
#   request = self._build_request_config(
# [{'type': 'text', 'text': 'Helping a law firm adopt **Agentic AI**—AI systems that can autonomously plan, use tools, execute multi-step complex workflows, and self-correct—is a massive business opportunity. \n\nUnlike standard Generative AI (which just answers a prompt), **Agentic AI acts like a virtual junior associate.** It can take a broad goal (e.g., *"Prepare a draft motion to dismiss based on breach of contract, using our internal firm precedents and recent state case law"*), break it down into tasks, search databases, write sections, cross-check its own citations, and hand a polished draft to a partner.\n\nHere is a step-by-step roadmap to help a law firm successfully implement and scale Agentic AI.\n\n---\n\n### Phase 1: Educate and Frame the Value\nLawyers are risk-averse, precedent-driven, and hyper-focused on accuracy. To get buy-in, you must bridge the gap between "Generative AI" (chatbots) and "Agentic AI" (workflow automation).\n\n*   **Shift the Mindset:** Position Agentic AI not as a replacement for lawyers, but as a **"Digital Associate"** that handles tedious execution while partners handle strategy, client relationships, and judgment.\n*   **Address the Billable Hour Dilemma:** Address the fear that efficiency destroys revenue. Explain how AI enables **alternative fee arrangements (AFAs)**, allows the firm to take on **2–3x more case volume**, and prevents burnout among associates.\n\n---\n\n### Phase 2: Identify High-Impact Use Cases\nDon\'t try to automate everything at once. Focus on workflows that involve multi-step, rules-based, or document-heavy processes.\n\n#### 1. Litigation Support Agents\n*   **Case Strategy & Research Agent:** Receives a complaint -> extracts key claims -> autonomously searches LexisNexis/Westlaw and internal repositories -> builds a case law matrix -> drafts a preliminary defense strategy memo.\n*   **Deposition Preparation Agent:** Scans thousands of discovery documents, emails, and prior transcripts -> flags inconsistencies -> generates a prioritized deposition outline with hyperlinked evidence.\n\n#### 2. Corporate & Transactional Agents\n*   **Due Diligence Agent:** Reads 500+ vendor agreements -> flags non-standard change-of-control or indemnity clauses -> organizes findings into a risk matrix -> drafts the due diligence report schedule.\n*   **Contract Negotiation Agent:** Compares incoming opposing counsel redlines against the firm’s playbook -> autonomously accepts low-risk edits -> drafts alternative counter-proposals for high-risk clauses with justification notes for the lead attorney.\n\n#### 3. Administrative & Operational Agents\n*   **Client Intake & Conflict Check Agent:** Interacts with prospective clients -> gathers matter details -> runs background conflict checks against internal databases -> routes clean matters to the appropriate partner.\n\n---\n\n### Phase 3: Establish the Security & Risk Architecture\nThis is the most critical step. Law firms will not adopt AI if it risks attorney-client privilege, client confidentiality, or creates malpractice liability.\n\n*   **Enforce "Human-in-the-Loop" (HITL):** Design agents so they **never** perform an external action (sending an email, filing a motion, communicating with a client) without explicit attorney approval.\n*   **Zero Data Retention & Enterprise Privacy:** Ensure AI models do not train on the firm’s or client’s data. Use private cloud instances (Azure OpenAI, AWS Bedrock, or dedicated legal tech stacks like Harvey, CoCounsel, or Lexis+ AI).\n*   **Auditability & Traceability:** Build agent workflows that log *why* the AI made a decision and provide direct, hyperlinked pin-point citations to source documents for every claim made.\n\n---\n\n### Phase 4: Build a "Crawl, Walk, Run" Implementation Strategy\n\n#### **Step 1: Crawl (Days 1–30) — The Pilot Program**\n*   Pick **one specific practice group** (e.g., Real Estate, Insurance Defense, or M&A) that has standardized, repetitive document workflows.\n*   ...
